# %% [markdown]
# # Тема работы: "Психологическое здоровье студентов"

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Для работы был взят датасет "**Student Mental health**". Этот набор данных был собран в ходе опроса, проведенного с помощью *Google Forms* среди студентов университета с целью изучения их текущей академической успеваемости и психического здоровья. Все **данные** были получены из Малайзии и **предоставлены IIUM** (Международным университетом Икамил, Малайзия).
#
# В данной работе будет устанавливаться **зависимость** между **психологическим состоянием** студентов и их **успеваемостью**, а также возможная **взаимосвязь** между **возрастом, полом, изучаемым курсом и семейным положением**.
#
# Также важно обратить внимание на систему оценивания в данном университете. Для оценки успеваемости студентов используется **CGPA**. CGPA означает совокупный средний балл успеваемости. Обычно он используется для измерения общей академической успеваемости студента. CGPA рассчитывается путем получения среднего балла, который студент получает за каждый семестр, и делится на общее количество зачетных единиц. В данном университете **4 - максимум, а 0 - минимум**.

# %% [markdown]
# ### Расшифровка наименований специальностей:
# 1.	accounting – Учет
# 2.	ala – «Faculty of Islamic Studies» (Факультет Исламских Исследований)
# 3.	banking studies - Банковское дело
# 4.	bcs - Информатика и компьютерные науки
# 5.	benl – «Faculty of Business and Economics» (Факультет Бизнеса и Экономики)
# 6.	biomedical science - Биомедицинская наука
# 7.	biotechnology - Биотехнологии
# 8.	bit - Информационные технологии
# 9.	business administration - Управление бизнесом
# 10.	 communication - Коммуникации
# 11.	 cts - Системы компьютерного обучения
# 12.	 diploma nursing - Диплом в области сестринского дела
# 13.	 diploma tesl - Диплом в области преподавания английского как второго языка
# 14.	 econs - Экономика
# 15.	 engineering (engin/engine) - Инженерия
# 16.	 enm - Управление
# 17.	 fiqh - Исламское право
# 18.	 fiqh fatwa - Фетва в области исламского права
# 19.	 human resources - Управление персоналом
# 20.	 human sciences - Гуманитарные науки
# 21.	 irkhs - Информационные и коммуникационные науки
# 22.	 islamic education - Исламское образование
# 23.	 it - Информационные технологии
# 24.	 kenms – «Centre for Knowledge Management and e-Learning Studies» (Центр Управления Знаниями и Исследований в области Электронного Обучения) или от «Centre for Knowledge Management and e-Learning» (Центр Управления Знаниями и Электронного Обучения)
# 25.	 kirkhs - Вероятно, это опечатка и должно быть «IRKHS» (Информационные и коммуникационные науки).
# 26.	 koe - Классическое образование
# 27.	 kop – «Centre for Knowledge and Research in Islamic Studies» (Центр Знаний и Исследований в Исламских Исследованиях)
# 28.	 law/laws – Право/Законодательство
# 29.	 malcom – «Faculty of Communication and Media Studies» (Факультет Коммуникаций и Медиа-исследований)
# 30.	 marine science - Морская наука
# 31.	 mathemathics - Математика
# 32.	 mhsc – «Faculty of Medicine and Health Sciences» (Факультет Медицины и Здравоохранения)
# 33.	 nursing - Сестринское дело
# 34.	 pendidikan islam - Исламское образование
# 35.	 psychology - Психология
# 36.	 radiography - Радиография
# 37.	 taasl - Возможно, это сокращение от «Centre for Teaching and Learning» (Центр Преподавания и Обучения) или «Teaching and Learning Centre», которые находятся в IIUM
# 38.	 usuluddin - Усулуддин (исламское богословие)

# %% [markdown]
# # Цели и задачи проекта

# %% [markdown]
# ### Цель исследования:
# Повысить успеваемость студентов.
#
# ### Задачи исследования:
# 1. Установить зависимость между психологическим состоянием студентов и их успеваемостью.
# 2. Придумать способы улучшить ментальное состояние студентов.

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## 1. Загрузка файла с данными и изучение общей информации

# %%
# @title
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# @title
data = pd.read_csv('Student Mental health.csv')
data
#data= pd.read_html('https://www.kaggle.com/datasets/shariful07/student-mental-health', match = 'Student Mental health')
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# 1                       year 2        3.00 - 3.49             No
# 2                       Year 1        3.00 - 3.49             No
# 3                       year 3        3.00 - 3.49            Yes
# 4                       year 4        3.00 - 3.49             No
# ..                         ...                ...            ...
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                       Yes                   No                       Yes
# 1                        No                  Yes                        No
# 2                       Yes                  Yes                       Yes
# 3                       Yes                   No                        No
# 4                        No                   No                        No
# ..                      ...                  ...                       ...
# 96                       No                  Yes                        No
# 97                      Yes                  Yes                        No
# 98                      Yes                   No                       Yes
# 99                       No                   No                        No
# 100                      No                   No                        No
#
#     Did you seek any specialist for a treatment?
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 96                                            No
# 97                                            No
# 98                                            No
# 99                                            No
# 100                                           No
#
# [101 rows x 11 columns]

# %% [markdown]
# Выводим строки датафрейма, чтобы бегло просмотреть данные и выявить отклонения.

# %%
# @title
data.head(10)
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
# 5  8/7/2020 12:31               Male  19.0          Engineering
# 6  8/7/2020 12:32             Female  23.0     Pendidikan islam
# 7  8/7/2020 12:33             Female  18.0                  BCS
# 8  8/7/2020 12:35             Female  19.0      Human Resources
# 9  8/7/2020 12:39               Male  18.0                Irkhs
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
# 5                     Year 2        3.50 - 4.00             No
# 6                     year 2       3.50 - 4.00             Yes
# 7                     year 1        3.50 - 4.00             No
# 8                     Year 2        2.50 - 2.99             No
# 9                     year 1        3.50 - 4.00             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
# 5                      No                   No                       Yes
# 6                     Yes                   No                       Yes
# 7                      No                  Yes                        No
# 8                      No                   No                        No
# 9                      No                  Yes                       Yes
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
# 5                                           No
# 6                                           No
# 7                                           No
# 8                                           No
# 9                                           No

# %%
# @title
data.tail(10)
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 91   13/07/2020 14:38:12               Male  18.0                  Koe
# 92   13/07/2020 14:48:05             Female  19.0                  KOE
# 93   13/07/2020 16:15:13             Female  18.0                 BENL
# 94   13/07/2020 17:30:44             Female  24.0                 Fiqh
# 95   13/07/2020 19:08:32             Female  18.0    Islamic Education
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 91                      Year 2        3.00 - 3.49             No
# 92                      year 2        3.00 - 3.49            Yes
# 93                      year 1        3.00 - 3.49             No
# 94                      Year 3           0 - 1.99             No
# 95                      year 1        3.50 - 4.00             No
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 91                       No                  Yes                        No
# 92                      Yes                   No                        No
# 93                      Yes                   No                        No
# 94                       No                   No                       Yes
# 95                       No                   No                        No
# 96                       No                  Yes                        No
# 97                      Yes                  Yes                        No
# 98                      Yes                   No                       Yes
# 99                       No                   No                        No
# 100                      No                   No                        No
#
#     Did you seek any specialist for a treatment?
# 91                                            No
# 92                                            No
# 93                                            No
# 94                                            No
# 95                                            No
# 96                                            No
# 97                                            No
# 98                                            No
# 99                                            No
# 100                                           No

# %%
# @title
data.sample(10)   # Случайная выборка строк
# Out:
#               Timestamp Choose your gender   Age What is your course?  \
# 93  13/07/2020 16:15:13             Female  18.0                 BENL
# 34       8/7/2020 14:41             Female  19.0                  BIT
# 69       8/7/2020 19:32             Female  24.0                  Kop
# 73        9/7/2020 6:57               Male  18.0   Biomedical science
# 62       8/7/2020 17:05             Female  18.0                  CTS
# 55       8/7/2020 15:58               Male  21.0                  BCS
# 57       8/7/2020 16:21             Female  20.0                 BENL
# 28       8/7/2020 13:58             Female  24.0                  BIT
# 37       8/7/2020 14:45             Female  19.0                  BIT
# 21       8/7/2020 13:13             Female  18.0                  KOE
#
#    Your current year of Study What is your CGPA? Marital status  \
# 93                     year 1        3.00 - 3.49             No
# 34                     year 1        3.00 - 3.49             No
# 69                     year 4        3.00 - 3.49             No
# 73                     year 1           0 - 1.99             No
# 62                     Year 1        3.50 - 4.00             No
# 55                     year 1        3.00 - 3.49             No
# 57                     Year 3        3.00 - 3.49             No
# 28                     Year 3        3.50 - 4.00            Yes
# 37                     year 1        2.50 - 2.99             No
# 21                     Year 2        3.00 - 3.49             No
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 93                     Yes                   No                        No
# 34                     Yes                  Yes                       Yes
# 69                      No                  Yes                        No
# 73                      No                   No                        No
# 62                      No                   No                       Yes
# 55                      No                   No                        No
# 57                     Yes                  Yes                        No
# 28                     Yes                  Yes                       Yes
# 37                     Yes                  Yes                       Yes
# 21                      No                   No                        No
#
#    Did you seek any specialist for a treatment?
# 93                                           No
# 34                                           No
# 69                                           No
# 73                                           No
# 62                                           No
# 55                                           No
# 57                                           No
# 28                                          Yes
# 37                                           No
# 21                                           No

# %% [markdown]
# Этим способом можно вывести такую информацию о датафрейме, как размер занимаемой памяти, место сохранения и т.д.

# %%
# @title
data.info
# Out:
# <bound method DataFrame.info of                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# 1                       year 2        3.00 - 3.49             No
# 2                       Year 1        3.00 - 3.49             No
# 3                       year 3        3.00 - 3.49            Yes
# 4                       year 4        3.00 - 3.49             No
# ..                         ...                ...            ...
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                       Yes                   No                       Yes
# 1                        No                  Yes                        No
# 2                       Yes                  Yes                       Yes
# 3                       Yes                   No                        No
# 4                        No                   No                        No
# ..                      ...                  ...                       ...
# 96                       No                  Yes                        No
# 97                      Yes                  Yes                        No
# 98                      Yes                   No                       Yes
# 99                       No                   No                        No
# 100                      No                   No                        No
#
#     Did you seek any specialist for a treatment?
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 96                                            No
# 97                                            No
# 98                                            No
# 99                                            No
# 100                                           No
#
# [101 rows x 11 columns]>

# %% [markdown]
# Просмотр типов данных в датафрейме.

# %%
# @title
data.dtypes
# Out:
# Timestamp                                        object
# Choose your gender                               object
# Age                                             float64
# What is your course?                             object
# Your current year of Study                       object
# What is your CGPA?                               object
# Marital status                                   object
# Do you have Depression?                          object
# Do you have Anxiety?                             object
# Do you have Panic attack?                        object
# Did you seek any specialist for a treatment?     object
# dtype: object

# %% [markdown]
# Посмотрим количество строк и столбцов, а затем выведем их названия.

# %%
# @title
data.shape
# Out:
# (101, 11)

# %%
# @title
# Строки
data.shape[0]
# Out:
# 101

# %%
# @title
# Столбцы
data.shape[1]
# Out:
# 11

# %%
# @title
data.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %% [markdown]
# Узнаем сколько места занимает датафрейм, а также количество ненулевых значений по столбцам.

# %%
# @title
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
#  9   Do you have Panic attack?                     101 non-null    object
#  10  Did you seek any specialist for a treatment?  101 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 8.8+ KB

# %%
# @title
data.memory_usage()
# Out:
# Index                                           128
# Timestamp                                       808
# Choose your gender                              808
# Age                                             808
# What is your course?                            808
# Your current year of Study                      808
# What is your CGPA?                              808
# Marital status                                  808
# Do you have Depression?                         808
# Do you have Anxiety?                            808
# Do you have Panic attack?                       808
# Did you seek any specialist for a treatment?    808
# dtype: int64

# %% [markdown]
# ### **Выводы**

# %% [markdown]
# 1. В датафрейме 101 строка (вместе с заголовками столбцов), 11 столбцов.
# 2. В 1 столбце имеется 1 пропущенное значение.
# 3. Нарушение стиля в заголовках столбцов.
# 4. Для ряда столбцов можно изменить тип данных для снижения нагрузки и удобства визуализации данных.
# 5. Более детально необходимо посмотреть на строковые значения в столбцах **your_study_time** (смешаны строковые и целочисленные значения); **timestamp** (начиная с 77 строки записи не подходят под тип даты).
# 6. Столбец **cgpa** следует привести к значениям типа *float*, заменив диапазон на среднее значение ячейки.

# %% [markdown]
# ### Проверьте корректность наименований столбцов, соответствие «змеиному регистру». Приведите наименования столбцов и весь текст в датафрейме к единому (нижнему) регистру.

# %% [markdown]
# `data.columns` — это объект, представляющий названия всех столбцов в датафрейме.
#
# `.str.lower()` — это метод, который применяется к каждому элементу (названию столбца) в созданном объекте, чтобы преобразовать все буквы в строчные.
#
# `.str.replace(' ', '_')` — это метод, который заменяет пробелы в названиях столбцов на символ подчеркивания.

# %%
# @title
# Для начала изменим названия столбцов
data.columns = data.columns.str.lower().str.replace(' ', '_')
data
# Out:
#                timestamp choose_your_gender   age what_is_your_course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     your_current_year_of_study what_is_your_cgpa? marital_status  \
# 0                       year 1        3.00 - 3.49             No
# 1                       year 2        3.00 - 3.49             No
# 2                       Year 1        3.00 - 3.49             No
# 3                       year 3        3.00 - 3.49            Yes
# 4                       year 4        3.00 - 3.49             No
# ..                         ...                ...            ...
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     do_you_have_depression? do_you_have_anxiety? do_you_have_panic_attack?  \
# 0                       Yes                   No                       Yes
# 1                        No                  Yes                        No
# 2                       Yes                  Yes                       Yes
# 3                       Yes                   No                        No
# 4                        No                   No                        No
# ..                      ...                  ...                       ...
# 96                       No                  Yes                        No
# 97                      Yes                  Yes                        No
# 98                      Yes                   No                       Yes
# 99                       No                   No                        No
# 100                      No                   No                        No
#
#     did_you_seek_any_specialist_for_a_treatment?
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 96                                            No
# 97                                            No
# 98                                            No
# 99                                            No
# 100                                           No
#
# [101 rows x 11 columns]

# %% [markdown]
#  `applymap()` применяется ко всем элементам датафрейма
#  `lambda x: x.lower() if isinstance(x, str) else x` - это лямбда-функция(анонимные функции, которые могут включать только одно выражение. Лямбда-функции могут принимать любое количество аргументов, но могут возвращать только одно значение), которая преобразует каждый элемент `x` в нижний регистр, если `x` является строкой, в противном случае возвращает `x` без изменений.

# %%
# @title
data = data.applymap(lambda x: x.lower() if isinstance(x, str) else x)
data
# Out:
# <ipython-input-15-3d300ba259d3>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(lambda x: x.lower() if isinstance(x, str) else x)
#                timestamp choose_your_gender   age what_is_your_course?  \
# 0         8/7/2020 12:02             female  18.0          engineering
# 1         8/7/2020 12:04               male  21.0    islamic education
# 2         8/7/2020 12:05               male  19.0                  bit
# 3         8/7/2020 12:06             female  22.0                 laws
# 4         8/7/2020 12:13               male  23.0         mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             female  21.0                  bcs
# 97   13/07/2020 21:21:42               male  18.0          engineering
# 98   13/07/2020 21:22:56             female  19.0             nursing
# 99   13/07/2020 21:23:57             female  23.0     pendidikan islam
# 100  18/07/2020 20:16:21               male  20.0   biomedical science
#
#     your_current_year_of_study what_is_your_cgpa? marital_status  \
# 0                       year 1        3.00 - 3.49             no
# 1                       year 2        3.00 - 3.49             no
# 2                       year 1        3.00 - 3.49             no
# 3                       year 3        3.00 - 3.49            yes
# 4                       year 4        3.00 - 3.49             no
# ..                         ...                ...            ...
# 96                      year 1        3.50 - 4.00             no
# 97                      year 2        3.00 - 3.49             no
# 98                      year 3        3.50 - 4.00            yes
# 99                      year 4        3.50 - 4.00             no
# 100                     year 2        3.00 - 3.49             no
#
#     do_you_have_depression? do_you_have_anxiety? do_you_have_panic_attack?  \
# 0                       yes                   no                       yes
# 1                        no                  yes                        no
# 2                       yes                  yes                       yes
# 3                       yes                   no                        no
# 4                        no                   no                        no
# ..                      ...                  ...                       ...
# 96                       no                  yes                        no
# 97                      yes                  yes                        no
# 98                      yes                   no                       yes
# 99                       no                   no                        no
# 100                      no                   no                        no
#
#     did_you_seek_any_specialist_for_a_treatment?
# 0                                             no
# 1                                             no
# 2                                             no
# 3                                             no
# 4                                             no
# ..                                           ...
# 96                                            no
# 97                                            no
# 98                                            no
# 99                                            no
# 100                                           no
#
# [101 rows x 11 columns]

# %% [markdown]
# Переименуем столбцы для удобной работы с ними, а также соответствия "змеиному" стилю.

# %%
# @title
data.rename(columns = {'choose_your_gender':'gender'}, inplace=True)
data.rename(columns = {'your_current_year_of_study':'study_time'}, inplace=True)
data.rename(columns = {'what_is_your_cgpa?':'cgpa'}, inplace=True)
data.rename(columns = {'what_is_your_course?':'name_of_course'}, inplace=True)
data.rename(columns = {'do_you_have_depression?':'depression'}, inplace=True)
data.rename(columns = {'do_you_have_anxiety?':'anxiety'}, inplace=True)
data.rename(columns = {'do_you_have_panic_attack?':'panic_attack'}, inplace=True)
data.rename(columns = {'did_you_seek_any_specialist_for_a_treatment?':'treatment'}, inplace=True)
data
# Out:
#                timestamp  gender   age      name_of_course study_time  \
# 0         8/7/2020 12:02  female  18.0         engineering     year 1
# 1         8/7/2020 12:04    male  21.0   islamic education     year 2
# 2         8/7/2020 12:05    male  19.0                 bit     year 1
# 3         8/7/2020 12:06  female  22.0                laws     year 3
# 4         8/7/2020 12:13    male  23.0        mathemathics     year 4
# ..                   ...     ...   ...                 ...        ...
# 96   13/07/2020 19:56:49  female  21.0                 bcs     year 1
# 97   13/07/2020 21:21:42    male  18.0         engineering     year 2
# 98   13/07/2020 21:22:56  female  19.0            nursing      year 3
# 99   13/07/2020 21:23:57  female  23.0    pendidikan islam     year 4
# 100  18/07/2020 20:16:21    male  20.0  biomedical science     year 2
#
#             cgpa marital_status depression anxiety panic_attack treatment
# 0    3.00 - 3.49             no        yes      no          yes        no
# 1    3.00 - 3.49             no         no     yes           no        no
# 2    3.00 - 3.49             no        yes     yes          yes        no
# 3    3.00 - 3.49            yes        yes      no           no        no
# 4    3.00 - 3.49             no         no      no           no        no
# ..           ...            ...        ...     ...          ...       ...
# 96   3.50 - 4.00             no         no     yes           no        no
# 97   3.00 - 3.49             no        yes     yes           no        no
# 98   3.50 - 4.00            yes        yes      no          yes        no
# 99   3.50 - 4.00             no         no      no           no        no
# 100  3.00 - 3.49             no         no      no           no        no
#
# [101 rows x 11 columns]

# %% [markdown]
# ## 2. Изучение пропущенных значений

# %% [markdown]
# Проверьте датафрейм на пропуски. Заполните пропущенные значения.
# Для каждой замены укажите, почему пропущенные значения заполняются именно
# таким образом. (NB! Если строки с пропусками составляют не более 5% от
# общего числа строк и заполнить их не представляется возможным, в этом случае
# строки можно удалить.)

# %%
# @title
data.count()   # Количество ненулевых значений
# Out:
# timestamp         101
# gender            101
# age               100
# name_of_course    101
# study_time        101
# cgpa              101
# marital_status    101
# depression        101
# anxiety           101
# panic_attack      101
# treatment         101
# dtype: int64

# %%
# @title
data.isnull().sum()
# Out:
# timestamp         0
# gender            0
# age               1
# name_of_course    0
# study_time        0
# cgpa              0
# marital_status    0
# depression        0
# anxiety           0
# panic_attack      0
# treatment         0
# dtype: int64

# %% [markdown]
# `isnull()` возвращает булевое значение, указывающее, содержит ли каждая строка/столбец `NaN`. `any(axis=1)` используется, чтобы выполнять поиск по строкам.

# %%
# @title
null_values = data[data.isnull().any(axis=1)]
print("Строка, содержащая нулевое значение:")
print(null_values)
# Out:
# Строка, содержащая нулевое значение:
#          timestamp gender  age name_of_course study_time      cgpa  \
# 43  8/7/2020 15:07   male  NaN            bit     year 1  0 - 1.99
#
#    marital_status depression anxiety panic_attack treatment
# 43             no         no      no           no        no

# %% [markdown]
# Заполнение пропущенных значений зависит от контекста данных. Например:
#
# - Для числовых столбцов возможно использование среднего или медианного значения.
# - Для категориальных столбцов использование наиболее частого значения (мода).
#
# Если строки с пропусками составляют менее 5%, их можно удалить:

# %%
# @title
data.dropna(inplace=True)
data.count()
# Out:
# timestamp         100
# gender            100
# age               100
# name_of_course    100
# study_time        100
# cgpa              100
# marital_status    100
# depression        100
# anxiety           100
# panic_attack      100
# treatment         100
# dtype: int64

# %% [markdown]
# Я воспользовалась удалением строки, т.к. возраст опрошенного нельзя узнать наверняка.

# %% [markdown]
# ## 3. Изменение типов данных

# %% [markdown]
#  Измените типы данных в столбцах, где это необходимо, объясните
# изменения.

# %% [markdown]
#  - `['study_time']. str.extract (r '(\ d+)', expand = false)` извлекает числа, используя регулярное выражение `r '(\ d+)'`.Этот шаблон соответствует одной или нескольким цифрам.
#  - `exprand = false` гарантирует, что возвращаются только извлеченные числа, а не отдельный фрейм данных.
#  - `astype (int)` преобразует извлеченные числа в целые числа.

# %%
# @title
# Удаляем текстовые значения из столбца "study_time" и оставляем только числа, преобразуя к типу int
data['study_time'] = data['study_time'].str.extract(r'(\d+)', expand=False).astype(int)
data
# Out:
#                timestamp  gender   age      name_of_course  study_time  \
# 0         8/7/2020 12:02  female  18.0         engineering           1
# 1         8/7/2020 12:04    male  21.0   islamic education           2
# 2         8/7/2020 12:05    male  19.0                 bit           1
# 3         8/7/2020 12:06  female  22.0                laws           3
# 4         8/7/2020 12:13    male  23.0        mathemathics           4
# ..                   ...     ...   ...                 ...         ...
# 96   13/07/2020 19:56:49  female  21.0                 bcs           1
# 97   13/07/2020 21:21:42    male  18.0         engineering           2
# 98   13/07/2020 21:22:56  female  19.0            nursing            3
# 99   13/07/2020 21:23:57  female  23.0    pendidikan islam           4
# 100  18/07/2020 20:16:21    male  20.0  biomedical science           2
#
#             cgpa marital_status depression anxiety panic_attack treatment
# 0    3.00 - 3.49             no        yes      no          yes        no
# 1    3.00 - 3.49             no         no     yes           no        no
# 2    3.00 - 3.49             no        yes     yes          yes        no
# 3    3.00 - 3.49            yes        yes      no           no        no
# 4    3.00 - 3.49             no         no      no           no        no
# ..           ...            ...        ...     ...          ...       ...
# 96   3.50 - 4.00             no         no     yes           no        no
# 97   3.00 - 3.49             no        yes     yes           no        no
# 98   3.50 - 4.00            yes        yes      no          yes        no
# 99   3.50 - 4.00             no         no      no           no        no
# 100  3.00 - 3.49             no         no      no           no        no
#
# [100 rows x 11 columns]

# %%
# @title
data['cgpa'] = data['cgpa'].apply(lambda x: sum(map(float, x.split('-'))) / 2 if '-' in x else float(x))
data
# Out:
#                timestamp  gender   age      name_of_course  study_time   cgpa  \
# 0         8/7/2020 12:02  female  18.0         engineering           1  3.245
# 1         8/7/2020 12:04    male  21.0   islamic education           2  3.245
# 2         8/7/2020 12:05    male  19.0                 bit           1  3.245
# 3         8/7/2020 12:06  female  22.0                laws           3  3.245
# 4         8/7/2020 12:13    male  23.0        mathemathics           4  3.245
# ..                   ...     ...   ...                 ...         ...    ...
# 96   13/07/2020 19:56:49  female  21.0                 bcs           1  3.750
# 97   13/07/2020 21:21:42    male  18.0         engineering           2  3.245
# 98   13/07/2020 21:22:56  female  19.0            nursing            3  3.750
# 99   13/07/2020 21:23:57  female  23.0    pendidikan islam           4  3.750
# 100  18/07/2020 20:16:21    male  20.0  biomedical science           2  3.245
#
#     marital_status depression anxiety panic_attack treatment
# 0               no        yes      no          yes        no
# 1               no         no     yes           no        no
# 2               no        yes     yes          yes        no
# 3              yes        yes      no           no        no
# 4               no         no      no           no        no
# ..             ...        ...     ...          ...       ...
# 96              no         no     yes           no        no
# 97              no        yes     yes           no        no
# 98             yes        yes      no          yes        no
# 99              no         no      no           no        no
# 100             no         no      no           no        no
#
# [100 rows x 11 columns]

# %% [markdown]
# - Мы используем метод `apply`, чтобы применить функцию к каждому значению в столбце "*cgpa*".
# - Если в значении есть тире, оно будет разделено, и каждое значение преобразуется в флоат. Затем мы суммируем эти значения и делим на 2 для получения среднего.
# - Если тире нет, просто преобразуем значение в флоат.

# %% [markdown]
# 1. Значения столца "name_of_course" engin, engine переименуем в engineering, т.к. это одна и та же специальность.
# 2. Также поступим со значениями laws и law.

# %%
# Переименование значений в столбце 'name_of_course'
data['name_of_course'] = data['name_of_course'].replace({'engin':'engineering',
                                                         'engine':'engineering',
                                                         'laws':'law',
                                                         'diploma nursing':'nursing'})

# %% [markdown]
# Проблема в том, что в столбце 'name_of_course' есть невидимые пробелы или непечатные символы в начале или конце названия курсов.

# %%
data['name_of_course'] = data['name_of_course'].str.strip() # Удаление пробелов в начале и конце

# %% [markdown]
# Приведём столбец `timestamp` к типу время.

# %%
# @title
data['timestamp'] = pd.to_datetime(data['timestamp'], format='mixed')
data
# Out:
#               timestamp  gender   age      name_of_course  study_time   cgpa  \
# 0   2020-08-07 12:02:00  female  18.0         engineering           1  3.245
# 1   2020-08-07 12:04:00    male  21.0   islamic education           2  3.245
# 2   2020-08-07 12:05:00    male  19.0                 bit           1  3.245
# 3   2020-08-07 12:06:00  female  22.0                 law           3  3.245
# 4   2020-08-07 12:13:00    male  23.0        mathemathics           4  3.245
# ..                  ...     ...   ...                 ...         ...    ...
# 96  2020-07-13 19:56:49  female  21.0                 bcs           1  3.750
# 97  2020-07-13 21:21:42    male  18.0         engineering           2  3.245
# 98  2020-07-13 21:22:56  female  19.0             nursing           3  3.750
# 99  2020-07-13 21:23:57  female  23.0    pendidikan islam           4  3.750
# 100 2020-07-18 20:16:21    male  20.0  biomedical science           2  3.245
#
#     marital_status depression anxiety panic_attack treatment
# 0               no        yes      no          yes        no
# 1               no         no     yes           no        no
# 2               no        yes     yes          yes        no
# 3              yes        yes      no           no        no
# 4               no         no      no           no        no
# ..             ...        ...     ...          ...       ...
# 96              no         no     yes           no        no
# 97              no        yes     yes           no        no
# 98             yes        yes      no          yes        no
# 99              no         no      no           no        no
# 100             no         no      no           no        no
#
# [100 rows x 11 columns]

# %% [markdown]
# Изменим типы данных остальных стобцов и проверим изменения.

# %%
# @title
data = data.astype({
    'gender':'str',
    'name_of_course':'string',
    'cgpa':'float',
    'gender':'string',
    'marital_status':'string',
    'depression':'string',
    'anxiety':'string',
    'panic_attack':'string',
    'treatment':'string',
    'age':'int64'})
data.dtypes
# Out:
# timestamp         datetime64[ns]
# gender            string[python]
# age                        int64
# name_of_course    string[python]
# study_time                 int64
# cgpa                     float64
# marital_status    string[python]
# depression        string[python]
# anxiety           string[python]
# panic_attack      string[python]
# treatment         string[python]
# dtype: object

# %% [markdown]
# ## 4. Поиск дубликатов

# %% [markdown]
#  Выполните поиск дубликатов в данных. Объясните наличие дубликатов
# (если таковые имеются). Выполните удаление дубликатов.

# %%
# @title
duplicates = data.duplicated().sum()
print(f"Количество дубликатов: {duplicates}")
# Out:
# Количество дубликатов: 0

# %% [markdown]
#    * Если `inplace=True`, метод удаляет дубликаты из исходного датафрейма и возвращает `None`.
#    * Если `inplace=False`, метод создает и возвращает новый датафрейм без дублей, оставляя исходный датафрейм неизмененным.

# %%
# @title
data.drop_duplicates(inplace=True)

# %% [markdown]
# ## 5. Выводы к разделу 1

# %% [markdown]
# Сделайте промежуточные выводы о проделанной работе.

# %% [markdown]
# - Столбец `cgpa` был преобразован к типу *float*, путём замены значения ячейки с диапазона на среднее.
# - Столбцы `age` и `study_time` были приведены к типу *int*.
# - Пропущенное значение было удалено для предупреждения ошибок при обработке данных.
# - Cтолб `timestamp` был приведён к типу *datatime*.
# - Дубликаты не были обнаружены.
# - После выполнения всех проверок и корректировок, я получила более чистый и структурированный датафрейм, который можно использовать для дальнейшего анализа.

# %% [markdown]
# # Исследовательский анализ данных

# %% [markdown]
# ## 1. Индексация (по координатам, логическая)

# %%
# @title
data
# Out:
#               timestamp  gender  age      name_of_course  study_time   cgpa  \
# 0   2020-08-07 12:02:00  female   18         engineering           1  3.245
# 1   2020-08-07 12:04:00    male   21   islamic education           2  3.245
# 2   2020-08-07 12:05:00    male   19                 bit           1  3.245
# 3   2020-08-07 12:06:00  female   22                 law           3  3.245
# 4   2020-08-07 12:13:00    male   23        mathemathics           4  3.245
# ..                  ...     ...  ...                 ...         ...    ...
# 96  2020-07-13 19:56:49  female   21                 bcs           1  3.750
# 97  2020-07-13 21:21:42    male   18         engineering           2  3.245
# 98  2020-07-13 21:22:56  female   19             nursing           3  3.750
# 99  2020-07-13 21:23:57  female   23    pendidikan islam           4  3.750
# 100 2020-07-18 20:16:21    male   20  biomedical science           2  3.245
#
#     marital_status depression anxiety panic_attack treatment
# 0               no        yes      no          yes        no
# 1               no         no     yes           no        no
# 2               no        yes     yes          yes        no
# 3              yes        yes      no           no        no
# 4               no         no      no           no        no
# ..             ...        ...     ...          ...       ...
# 96              no         no     yes           no        no
# 97              no        yes     yes           no        no
# 98             yes        yes      no          yes        no
# 99              no         no      no           no        no
# 100             no         no      no           no        no
#
# [100 rows x 11 columns]

# %% [markdown]
# Выполните индексацию по координаторам (не менее 5 различных
# условий) и логическую индексацию (не менее 5 различных условий). Выведите результаты.

# %%
# @title
data.loc[78, ]
# Out:
# timestamp         2020-07-13 10:07:32
# gender                         female
# age                                19
# name_of_course          biotechnology
# study_time                          3
# cgpa                            0.995
# marital_status                     no
# depression                         no
# anxiety                            no
# panic_attack                       no
# treatment                          no
# Name: 78, dtype: object

# %%
# @title
data.loc[data['depression'] == 'yes'].count()
# Out:
# timestamp         35
# gender            35
# age               35
# name_of_course    35
# study_time        35
# cgpa              35
# marital_status    35
# depression        35
# anxiety           35
# panic_attack      35
# treatment         35
# dtype: int64

# %%
# @title
data.loc[data['anxiety'] == 'yes'].count()
# Out:
# timestamp         34
# gender            34
# age               34
# name_of_course    34
# study_time        34
# cgpa              34
# marital_status    34
# depression        34
# anxiety           34
# panic_attack      34
# treatment         34
# dtype: int64

# %%
# @title
data.loc[data['panic_attack'] == 'yes'].count()
# Out:
# timestamp         33
# gender            33
# age               33
# name_of_course    33
# study_time        33
# cgpa              33
# marital_status    33
# depression        33
# anxiety           33
# panic_attack      33
# treatment         33
# dtype: int64

# %%
# @title
data.loc[(data['age'] == 18)].count()
# Out:
# timestamp         32
# gender            32
# age               32
# name_of_course    32
# study_time        32
# cgpa              32
# marital_status    32
# depression        32
# anxiety           32
# panic_attack      32
# treatment         32
# dtype: int64

# %%
# @title
data.loc[(data['age'] >= 20) &
    ((data['panic_attack'] == 'yes') |
    (data['anxiety'] == 'yes') |
    (data['depression'] == 'yes'))].count()
# Out:
# timestamp         29
# gender            29
# age               29
# name_of_course    29
# study_time        29
# cgpa              29
# marital_status    29
# depression        29
# anxiety           29
# panic_attack      29
# treatment         29
# dtype: int64

# %%
# @title
data.loc[(data['cgpa'] >= 3.75) & (data['gender'] == 'male')].count()
# Out:
# timestamp         9
# gender            9
# age               9
# name_of_course    9
# study_time        9
# cgpa              9
# marital_status    9
# depression        9
# anxiety           9
# panic_attack      9
# treatment         9
# dtype: int64

# %%
# @title
data.loc[(data['cgpa'] >= 3.75) & (data['gender'] == 'female')].count()
# Out:
# timestamp         39
# gender            39
# age               39
# name_of_course    39
# study_time        39
# cgpa              39
# marital_status    39
# depression        39
# anxiety           39
# panic_attack      39
# treatment         39
# dtype: int64

# %%
# @title
data.iloc[44:48, 7:12]
# Out:
#    depression anxiety panic_attack treatment
# 45         no     yes          yes        no
# 46         no     yes           no        no
# 47         no      no           no        no
# 48        yes      no           no        no

# %%
# @title
data.loc[(data['study_time'] >= 3) & (data['depression'] == 'yes')].count()
# Out:
# timestamp         11
# gender            11
# age               11
# name_of_course    11
# study_time        11
# cgpa              11
# marital_status    11
# depression        11
# anxiety           11
# panic_attack      11
# treatment         11
# dtype: int64

# %%
# @title
data.loc[(data['study_time'] >= 3) & (data['anxiety'] == 'yes')].count()
# Out:
# timestamp         10
# gender            10
# age               10
# name_of_course    10
# study_time        10
# cgpa              10
# marital_status    10
# depression        10
# anxiety           10
# panic_attack      10
# treatment         10
# dtype: int64

# %%
# @title
data.loc[(data['study_time'] < 3) & (data['panic_attack'] == 'yes')].count()
# Out:
# timestamp         22
# gender            22
# age               22
# name_of_course    22
# study_time        22
# cgpa              22
# marital_status    22
# depression        22
# anxiety           22
# panic_attack      22
# treatment         22
# dtype: int64

# %%
# @title
data[(data['treatment'] == 'no') &
    (data['depression'] == 'yes') &
    (data['anxiety'] == 'yes') &
    (data['panic_attack'] == 'yes')]
# Out:
#              timestamp  gender  age  name_of_course  study_time   cgpa  \
# 2  2020-08-07 12:05:00    male   19             bit           1  3.245
# 17 2020-08-07 12:52:00  female   24             enm           4  3.245
# 19 2020-08-07 13:07:00  female   18  marine science           2  3.750
# 24 2020-08-07 13:17:00  female   23             bcs           3  3.750
# 34 2020-08-07 14:41:00  female   19             bit           1  3.245
# 37 2020-08-07 14:45:00  female   19             bit           1  2.745
# 53 2020-08-07 15:48:00  female   20             koe           3  3.245
# 80 2020-07-13 10:11:26  female   24   communication           2  3.750
# 87 2020-07-13 11:46:13  female   18      psychology           1  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 2              no        yes     yes          yes        no
# 17            yes        yes     yes          yes        no
# 19            yes        yes     yes          yes        no
# 24             no        yes     yes          yes        no
# 34             no        yes     yes          yes        no
# 37             no        yes     yes          yes        no
# 53            yes        yes     yes          yes        no
# 80            yes        yes     yes          yes        no
# 87             no        yes     yes          yes        no

# %%
# @title
data[data['gender'] == 'male'].count()
# Out:
# timestamp         25
# gender            25
# age               25
# name_of_course    25
# study_time        25
# cgpa              25
# marital_status    25
# depression        25
# anxiety           25
# panic_attack      25
# treatment         25
# dtype: int64

# %%
# @title
data[data['gender'] == 'female'].count()
# Out:
# timestamp         75
# gender            75
# age               75
# name_of_course    75
# study_time        75
# cgpa              75
# marital_status    75
# depression        75
# anxiety           75
# panic_attack      75
# treatment         75
# dtype: int64

# %%
# @title
data[(data['treatment'] == 'yes') & (data['marital_status'] == 'yes')]
# Out:
#              timestamp  gender  age name_of_course  study_time   cgpa  \
# 28 2020-08-07 13:58:00  female   24            bit           3  3.750
# 33 2020-08-07 14:31:00    male   18            bcs           2  3.750
# 39 2020-08-07 14:56:00  female   24    engineering           2  2.745
# 50 2020-08-07 15:27:00  female   23            ala           1  2.745
#
#    marital_status depression anxiety panic_attack treatment
# 28            yes        yes     yes          yes       yes
# 33            yes        yes     yes           no       yes
# 39            yes        yes      no          yes       yes
# 50            yes        yes      no          yes       yes

# %%
# @title
data[data['name_of_course'] == 'law']
# Out:
#              timestamp  gender  age name_of_course  study_time   cgpa  \
# 3  2020-08-07 12:06:00  female   22            law           3  3.245
# 36 2020-08-07 14:43:00  female   18            law           3  3.245
# 71 2020-08-07 21:21:00  female   18            law           3  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 3             yes        yes      no           no        no
# 36             no        yes     yes           no        no
# 71             no         no      no          yes        no

# %%
# @title
data[data['age'] < 22]
# Out:
#               timestamp  gender  age      name_of_course  study_time   cgpa  \
# 0   2020-08-07 12:02:00  female   18         engineering           1  3.245
# 1   2020-08-07 12:04:00    male   21   islamic education           2  3.245
# 2   2020-08-07 12:05:00    male   19                 bit           1  3.245
# 5   2020-08-07 12:31:00    male   19         engineering           2  3.750
# 7   2020-08-07 12:33:00  female   18                 bcs           1  3.750
# ..                  ...     ...  ...                 ...         ...    ...
# 95  2020-07-13 19:08:32  female   18   islamic education           1  3.750
# 96  2020-07-13 19:56:49  female   21                 bcs           1  3.750
# 97  2020-07-13 21:21:42    male   18         engineering           2  3.245
# 98  2020-07-13 21:22:56  female   19             nursing           3  3.750
# 100 2020-07-18 20:16:21    male   20  biomedical science           2  3.245
#
#     marital_status depression anxiety panic_attack treatment
# 0               no        yes      no          yes        no
# 1               no         no     yes           no        no
# 2               no        yes     yes          yes        no
# 5               no         no      no          yes        no
# 7               no         no     yes           no        no
# ..             ...        ...     ...          ...       ...
# 95              no         no      no           no        no
# 96              no         no     yes           no        no
# 97              no        yes     yes           no        no
# 98             yes        yes      no          yes        no
# 100             no         no      no           no        no
#
# [62 rows x 11 columns]

# %% [markdown]
# ## 2. Сортировка данных

# %% [markdown]
# Выполните сортировку данных (по различным столбцам).
# Проанализируйте наибольшие и наименьшие значения, **сделайте выводы в
# рамках бизнес-задачи**.

# %%
# @title
data.sort_values(['cgpa', 'age'], ascending=True)
# Out:
#              timestamp  gender  age      name_of_course  study_time   cgpa  \
# 73 2020-09-07 06:57:00    male   18  biomedical science           1  0.995
# 78 2020-07-13 10:07:32  female   19       biotechnology           3  0.995
# 94 2020-07-13 17:30:44  female   24                fiqh           3  0.995
# 35 2020-08-07 14:43:00  female   18         engineering           1  2.245
# 89 2020-07-13 11:54:58    male   24         engineering           2  2.245
# ..                 ...     ...  ...                 ...         ...    ...
# 64 2020-08-07 17:46:00  female   24         engineering           1  3.750
# 74 2020-09-07 11:43:00    male   24                 bit           3  3.750
# 75 2020-09-07 11:57:00  female   24                 koe           1  3.750
# 80 2020-07-13 10:11:26  female   24       communication           2  3.750
# 81 2020-07-13 10:12:18  female   24             nursing           2  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 73             no         no      no           no        no
# 78             no         no      no           no        no
# 94             no         no      no          yes        no
# 35             no         no      no           no        no
# 89             no         no      no          yes        no
# ..            ...        ...     ...          ...       ...
# 64             no         no      no           no        no
# 74             no         no     yes           no        no
# 75             no         no     yes          yes        no
# 80            yes        yes     yes          yes        no
# 81             no         no      no           no        no
#
# [100 rows x 11 columns]

# %%
# @title
data.sort_values(['gender', 'name_of_course'], ascending=True)  # В алфавитном порядке
# Out:
#              timestamp  gender  age   name_of_course  study_time   cgpa  \
# 16 2020-08-07 12:46:00  female   24       accounting           3  3.245
# 50 2020-08-07 15:27:00  female   23              ala           1  2.745
# 25 2020-08-07 13:29:00  female   18  banking studies           1  3.750
# 7  2020-08-07 12:33:00  female   18              bcs           1  3.750
# 12 2020-08-07 12:40:00  female   18              bcs           1  3.245
# ..                 ...     ...  ...              ...         ...    ...
# 91 2020-07-13 14:38:12    male   18              koe           2  3.245
# 4  2020-08-07 12:13:00    male   23     mathemathics           4  3.245
# 67 2020-08-07 18:11:00    male   19             mhsc           3  3.245
# 84 2020-07-13 10:14:46    male   23      radiography           1  3.245
# 44 2020-08-07 15:08:00    male   23            taasl           2  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 16             no         no      no           no        no
# 50            yes        yes      no          yes       yes
# 25             no         no      no           no        no
# 7              no         no     yes           no        no
# 12             no        yes      no           no        no
# ..            ...        ...     ...          ...       ...
# 91             no         no     yes           no        no
# 4              no         no      no           no        no
# 67            yes        yes      no          yes        no
# 84             no         no      no           no        no
# 44             no         no      no          yes        no
#
# [100 rows x 11 columns]

# %%
# @title
max_age = data['age'].max()
min_age = data['age'].min()

print(f"Максимальный возраст: {max_age}, Минимальный возраст: {min_age}")
# Out:
# Максимальный возраст: 24, Минимальный возраст: 18

# %%
# @title
max_cgpa = data['cgpa'].max()
min_cgpa = data['cgpa'].min()

print(f"Лучшая оценка: {max_cgpa}, Худшая оценка: {min_cgpa}")
# Out:
# Лучшая оценка: 3.75, Худшая оценка: 0.995

# %% [markdown]
# ## 3. Фильтрация данных

# %% [markdown]
# Отфильтруйте строки на основе одного или нескольких условий,
# отобразите отфильтрованные данные. Для фильтрации используйте метод query
# (не менее 5 различных фильтров), оператор where (не менее 5 различных
# фильтров) и т.д. Фильтры должны отвечать бизнес-задаче.

# %%
# @title
data
# Out:
#               timestamp  gender  age      name_of_course  study_time   cgpa  \
# 0   2020-08-07 12:02:00  female   18         engineering           1  3.245
# 1   2020-08-07 12:04:00    male   21   islamic education           2  3.245
# 2   2020-08-07 12:05:00    male   19                 bit           1  3.245
# 3   2020-08-07 12:06:00  female   22                 law           3  3.245
# 4   2020-08-07 12:13:00    male   23        mathemathics           4  3.245
# ..                  ...     ...  ...                 ...         ...    ...
# 96  2020-07-13 19:56:49  female   21                 bcs           1  3.750
# 97  2020-07-13 21:21:42    male   18         engineering           2  3.245
# 98  2020-07-13 21:22:56  female   19             nursing           3  3.750
# 99  2020-07-13 21:23:57  female   23    pendidikan islam           4  3.750
# 100 2020-07-18 20:16:21    male   20  biomedical science           2  3.245
#
#     marital_status depression anxiety panic_attack treatment
# 0               no        yes      no          yes        no
# 1               no         no     yes           no        no
# 2               no        yes     yes          yes        no
# 3              yes        yes      no           no        no
# 4               no         no      no           no        no
# ..             ...        ...     ...          ...       ...
# 96              no         no     yes           no        no
# 97              no        yes     yes           no        no
# 98             yes        yes      no          yes        no
# 99              no         no      no           no        no
# 100             no         no      no           no        no
#
# [100 rows x 11 columns]

# %%
# @title
data.query('cgpa > 3 and marital_status == "yes"')
# Out:
#              timestamp  gender  age    name_of_course  study_time   cgpa  \
# 3  2020-08-07 12:06:00  female   22               law           3  3.245
# 6  2020-08-07 12:32:00  female   23  pendidikan islam           2  3.750
# 11 2020-08-07 12:39:00  female   24       engineering           3  3.750
# 17 2020-08-07 12:52:00  female   24               enm           4  3.245
# 19 2020-08-07 13:07:00  female   18    marine science           2  3.750
# 27 2020-08-07 13:41:00    male   18       engineering           2  3.245
# 28 2020-08-07 13:58:00  female   24               bit           3  3.750
# 33 2020-08-07 14:31:00    male   18               bcs           2  3.750
# 53 2020-08-07 15:48:00  female   20               koe           3  3.245
# 67 2020-08-07 18:11:00    male   19              mhsc           3  3.245
# 72 2020-08-07 22:35:00  female   19               bit           3  3.245
# 80 2020-07-13 10:11:26  female   24     communication           2  3.750
# 92 2020-07-13 14:48:05  female   19               koe           2  3.245
# 98 2020-07-13 21:22:56  female   19           nursing           3  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 3             yes        yes      no           no        no
# 6             yes        yes      no          yes        no
# 11            yes        yes      no           no        no
# 17            yes        yes     yes          yes        no
# 19            yes        yes     yes          yes        no
# 27            yes        yes     yes           no        no
# 28            yes        yes     yes          yes       yes
# 33            yes        yes     yes           no       yes
# 53            yes        yes     yes          yes        no
# 67            yes        yes      no          yes        no
# 72            yes        yes      no           no        no
# 80            yes        yes     yes          yes        no
# 92            yes        yes      no           no        no
# 98            yes        yes      no          yes        no

# %%
# @title
data.query('gender == "female" and treatment == "yes"')
# Out:
#              timestamp  gender  age name_of_course  study_time   cgpa  \
# 28 2020-08-07 13:58:00  female   24            bit           3  3.750
# 39 2020-08-07 14:56:00  female   24    engineering           2  2.745
# 50 2020-08-07 15:27:00  female   23            ala           1  2.745
# 54 2020-08-07 15:57:00  female   19            bcs           1  3.750
# 85 2020-07-13 10:33:47  female   18     psychology           1  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 28            yes        yes     yes          yes       yes
# 39            yes        yes      no          yes       yes
# 50            yes        yes      no          yes       yes
# 54             no        yes      no          yes       yes
# 85             no        yes     yes           no       yes

# %%
# @title
data.query('gender == "male" and treatment == "yes"')
# Out:
#              timestamp gender  age name_of_course  study_time  cgpa  \
# 33 2020-08-07 14:31:00   male   18            bcs           2  3.75
#
#    marital_status depression anxiety panic_attack treatment
# 33            yes        yes     yes           no       yes

# %%
# @title
data.query('study_time > 2 and cgpa >= 3.5')
# Out:
#              timestamp  gender  age    name_of_course  study_time  cgpa  \
# 11 2020-08-07 12:39:00  female   24       engineering           3  3.75
# 15 2020-08-07 12:43:00    male   24               bcs           3  3.75
# 24 2020-08-07 13:17:00  female   23               bcs           3  3.75
# 28 2020-08-07 13:58:00  female   24               bit           3  3.75
# 29 2020-08-07 14:05:00  female   24               bcs           4  3.75
# 41 2020-08-07 14:57:00  female   22       engineering           4  3.75
# 47 2020-08-07 15:14:00  female   18       engineering           4  3.75
# 49 2020-08-07 15:18:00  female   24               bcs           3  3.75
# 56 2020-08-07 16:08:00    male   23            kirkhs           3  3.75
# 71 2020-08-07 21:21:00  female   18               law           3  3.75
# 74 2020-09-07 11:43:00    male   24               bit           3  3.75
# 79 2020-07-13 10:10:30  female   18       engineering           4  3.75
# 90 2020-07-13 13:57:11  female   23      diploma tesl           3  3.75
# 98 2020-07-13 21:22:56  female   19           nursing           3  3.75
# 99 2020-07-13 21:23:57  female   23  pendidikan islam           4  3.75
#
#    marital_status depression anxiety panic_attack treatment
# 11            yes        yes      no           no        no
# 15             no         no      no           no        no
# 24             no        yes     yes          yes        no
# 28            yes        yes     yes          yes       yes
# 29             no         no      no           no        no
# 41             no         no      no           no        no
# 47             no         no      no           no        no
# 49             no         no      no          yes        no
# 56             no         no      no           no        no
# 71             no         no      no          yes        no
# 74             no         no     yes           no        no
# 79             no         no      no           no        no
# 90             no         no      no          yes        no
# 98            yes        yes      no          yes        no
# 99             no         no      no           no        no

# %%
# @title
data.query('gender == "female" and depression == "yes"').count()
# Out:
# timestamp         29
# gender            29
# age               29
# name_of_course    29
# study_time        29
# cgpa              29
# marital_status    29
# depression        29
# anxiety           29
# panic_attack      29
# treatment         29
# dtype: int64

# %%
# @title
data.query('gender == "female" and anxiety == "yes"').count()
# Out:
# timestamp         24
# gender            24
# age               24
# name_of_course    24
# study_time        24
# cgpa              24
# marital_status    24
# depression        24
# anxiety           24
# panic_attack      24
# treatment         24
# dtype: int64

# %%
# @title
data.query('gender == "female" and panic_attack == "yes"').count()
# Out:
# timestamp         25
# gender            25
# age               25
# name_of_course    25
# study_time        25
# cgpa              25
# marital_status    25
# depression        25
# anxiety           25
# panic_attack      25
# treatment         25
# dtype: int64

# %%
# @title
data.query('gender == "male" and panic_attack == "yes"').count()
# Out:
# timestamp         8
# gender            8
# age               8
# name_of_course    8
# study_time        8
# cgpa              8
# marital_status    8
# depression        8
# anxiety           8
# panic_attack      8
# treatment         8
# dtype: int64

# %%
# @title
data.query('gender == "male" and anxiety == "yes"').count()
# Out:
# timestamp         10
# gender            10
# age               10
# name_of_course    10
# study_time        10
# cgpa              10
# marital_status    10
# depression        10
# anxiety           10
# panic_attack      10
# treatment         10
# dtype: int64

# %%
# @title
data.query('gender == "male" and depression == "yes"').count()
# Out:
# timestamp         6
# gender            6
# age               6
# name_of_course    6
# study_time        6
# cgpa              6
# marital_status    6
# depression        6
# anxiety           6
# panic_attack      6
# treatment         6
# dtype: int64

# %%
# @title
count_depression = data.where(data['depression'] == 'yes').count()
count_anxiety = data.where(data['anxiety'] == 'yes').count()
count_panic_attack = data.where(data['panic_attack'] == 'yes').count()
print("Количество людей с \nдепрессией\n:", count_depression,
    "\nтревожностью\n:", count_anxiety,
    "\nдепрессией\n:", count_panic_attack)
# Out:
# Количество людей с
# депрессией
# : timestamp         35
# gender            35
# age               35
# name_of_course    35
# study_time        35
# cgpa              35
# marital_status    35
# depression        35
# anxiety           35
# panic_attack      35
# treatment         35
# dtype: int64
# тревожностью
# : timestamp         34
# gender            34
# age               34
# name_of_course    34
# study_time        34
# cgpa              34
# marital_status    34
# depression        34
# anxiety           34
# panic_attack      34
# treatment         34
# dtype: int64
# депрессией
# : timestamp         33
# gender            33
# age               33
# name_of_course    33
# study_time        33
# cgpa              33
# marital_status    33
# depression        33
# anxiety           33
# panic_attack      33
# treatment         33
# dtype: int64

# %%
# @title
data.where((data['depression'] == 'yes') & (data['marital_status'] == 'yes')).count()
# Out:
# timestamp         16
# gender            16
# age               16
# name_of_course    16
# study_time        16
# cgpa              16
# marital_status    16
# depression        16
# anxiety           16
# panic_attack      16
# treatment         16
# dtype: int64

# %%
# @title
data.where((data['anxiety'] == 'yes') & (data['marital_status'] == 'yes')).count()
# Out:
# timestamp         7
# gender            7
# age               7
# name_of_course    7
# study_time        7
# cgpa              7
# marital_status    7
# depression        7
# anxiety           7
# panic_attack      7
# treatment         7
# dtype: int64

# %%
# @title
data.where((data['panic_attack'] == 'yes') & (data['marital_status'] == 'yes')).count() # Таких нет
# Out:
# timestamp         10
# gender            10
# age               10
# name_of_course    10
# study_time        10
# cgpa              10
# marital_status    10
# depression        10
# anxiety           10
# panic_attack      10
# treatment         10
# dtype: int64

# %%
# @title
data.where((data['cgpa'] > 3.70) & (data['marital_status'] == 'yes')).count()
# Out:
# timestamp         7
# gender            7
# age               7
# name_of_course    7
# study_time        7
# cgpa              7
# marital_status    7
# depression        7
# anxiety           7
# panic_attack      7
# treatment         7
# dtype: int64

# %%
# @title
data.where((data['study_time'] >= 3) & (data['treatment'] == 'yes')).dropna()
# Out:
#              timestamp  gender   age name_of_course  study_time  cgpa  \
# 28 2020-08-07 13:58:00  female  24.0            bit         3.0  3.75
#
#    marital_status depression anxiety panic_attack treatment
# 28            yes        yes     yes          yes       yes

# %%
# @title
data.where((data['study_time'] < 3) & (data['treatment'] == 'yes')).dropna()
# Out:
#              timestamp  gender   age name_of_course  study_time   cgpa  \
# 33 2020-08-07 14:31:00    male  18.0            bcs         2.0  3.750
# 39 2020-08-07 14:56:00  female  24.0    engineering         2.0  2.745
# 50 2020-08-07 15:27:00  female  23.0            ala         1.0  2.745
# 54 2020-08-07 15:57:00  female  19.0            bcs         1.0  3.750
# 85 2020-07-13 10:33:47  female  18.0     psychology         1.0  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 33            yes        yes     yes           no       yes
# 39            yes        yes      no          yes       yes
# 50            yes        yes      no          yes       yes
# 54             no        yes      no          yes       yes
# 85             no        yes     yes           no       yes

# %% [markdown]
# ## 4. Сводные таблицы

# %% [markdown]
# > В рамках бизнес-задачи постройте несколько сводных таблиц. Объясните полученные результаты.

# %% [markdown]
# В каждом столбце есть повторяющееся значение, поэтому использовать функцию `.pivot()` для построения сводной таблицы не получится.

# %%
# @title
#data_pivot = data.pivot(index='time',
                    #values='treatment',
                    #columns='age')
#data_pivot.head(7)

# %%
# @title
data
# Out:
#               timestamp  gender  age      name_of_course  study_time   cgpa  \
# 0   2020-08-07 12:02:00  female   18         engineering           1  3.245
# 1   2020-08-07 12:04:00    male   21   islamic education           2  3.245
# 2   2020-08-07 12:05:00    male   19                 bit           1  3.245
# 3   2020-08-07 12:06:00  female   22                 law           3  3.245
# 4   2020-08-07 12:13:00    male   23        mathemathics           4  3.245
# ..                  ...     ...  ...                 ...         ...    ...
# 96  2020-07-13 19:56:49  female   21                 bcs           1  3.750
# 97  2020-07-13 21:21:42    male   18         engineering           2  3.245
# 98  2020-07-13 21:22:56  female   19             nursing           3  3.750
# 99  2020-07-13 21:23:57  female   23    pendidikan islam           4  3.750
# 100 2020-07-18 20:16:21    male   20  biomedical science           2  3.245
#
#     marital_status depression anxiety panic_attack treatment
# 0               no        yes      no          yes        no
# 1               no         no     yes           no        no
# 2               no        yes     yes          yes        no
# 3              yes        yes      no           no        no
# 4               no         no      no           no        no
# ..             ...        ...     ...          ...       ...
# 96              no         no     yes           no        no
# 97              no        yes     yes           no        no
# 98             yes        yes      no          yes        no
# 99              no         no      no           no        no
# 100             no         no      no           no        no
#
# [100 rows x 11 columns]

# %%
# @title
data.pivot_table(index=('depression', 'anxiety', 'panic_attack'), columns='treatment', values='timestamp', aggfunc='count')
# Out:
# treatment                          no  yes
# depression anxiety panic_attack
# no         no      no            36.0  NaN
#                    yes           13.0  NaN
#            yes     no            13.0  NaN
#                    yes            3.0  NaN
# yes        no      no            10.0  NaN
#                    yes            4.0  3.0
#            yes     no             6.0  2.0
#                    yes            9.0  1.0

# %% [markdown]
# Панические атаки чаще встречаются в сочетании с депрессией и тревожностью, или вообще без других расстройств.

# %%
# @title
data.pivot_table(values='age', index='cgpa', aggfunc=('mean','count'))
# Out:
#        count       mean
# cgpa
# 0.995      3  20.333333
# 2.245      2  21.000000
# 2.745      4  21.250000
# 3.245     43  20.372093
# 3.750     48  20.604167

# %% [markdown]
# Большая часть студентов хорошо учится.

# %%
# @title
data.pivot_table(values='cgpa', index='name_of_course', aggfunc=('mean', 'count'), columns='treatment')
# Out:
#                         count           mean
# treatment                  no  yes        no    yes
# name_of_course
# accounting                1.0  NaN  3.245000    NaN
# ala                       NaN  1.0       NaN  2.745
# banking studies           1.0  NaN  3.750000    NaN
# bcs                      16.0  2.0  3.623750  3.750
# benl                      3.0  NaN  3.245000    NaN
# biomedical science        4.0  NaN  2.682500    NaN
# biotechnology             1.0  NaN  0.995000    NaN
# bit                       8.0  1.0  3.308750  3.750
# business administration   1.0  NaN  3.245000    NaN
# communication             1.0  NaN  3.750000    NaN
# cts                       1.0  NaN  3.750000    NaN
# diploma tesl              1.0  NaN  3.750000    NaN
# econs                     1.0  NaN  3.750000    NaN
# engineering              19.0  1.0  3.378947  2.745
# enm                       1.0  NaN  3.245000    NaN
# fiqh                      1.0  NaN  0.995000    NaN
# fiqh fatwa                1.0  NaN  3.245000    NaN
# human resources           1.0  NaN  2.745000    NaN
# human sciences            1.0  NaN  3.245000    NaN
# irkhs                     1.0  NaN  3.750000    NaN
# islamic education         2.0  NaN  3.497500    NaN
# it                        1.0  NaN  3.245000    NaN
# kenms                     1.0  NaN  3.750000    NaN
# kirkhs                    2.0  NaN  3.750000    NaN
# koe                       6.0  NaN  3.329167    NaN
# kop                       1.0  NaN  3.245000    NaN
# law                       3.0  NaN  3.413333    NaN
# malcom                    1.0  NaN  3.750000    NaN
# marine science            1.0  NaN  3.750000    NaN
# mathemathics              1.0  NaN  3.245000    NaN
# mhsc                      1.0  NaN  3.245000    NaN
# nursing                   2.0  NaN  3.750000    NaN
# pendidikan islam          3.0  NaN  3.581667    NaN
# psychology                2.0  1.0  3.750000  3.750
# radiography               1.0  NaN  3.245000    NaN
# taasl                     1.0  NaN  3.750000    NaN
# usuluddin                 1.0  NaN  3.245000    NaN

# %% [markdown]
# Наиболее низкий сgpa был замечен у студентов курсов: biomedical science, benl, bit, engineering, koe. Чаще те, кто получает лечение лучше учатся.

# %%
# @title
data.pivot_table(index='age', values='cgpa', aggfunc=('mean', 'count'))
# Out:
#      count      mean
# age
# 18      32  3.427500
# 19      21  3.258571
# 20       6  3.413333
# 21       3  3.413333
# 22       2  3.497500
# 23      13  3.478462
# 24      23  3.345435

# %% [markdown]
# Наиболее низкий сgpa был замечен у студентов в  возрасте 19 лет, следом идут 24 летние.

# %% [markdown]
# ## 5. Группировка данных, агрегатные функции

# %% [markdown]
# > Сгруппируйте данные по определенному столбцу и вычислите агрегатные
# функции (сумма, среднее, минимальное, максимальное значение) для каждой
# группы (groupby + agg). Объясните полученные результаты.

# %%
# @title
data
# Out:
#               timestamp  gender  age      name_of_course  study_time   cgpa  \
# 0   2020-08-07 12:02:00  female   18         engineering           1  3.245
# 1   2020-08-07 12:04:00    male   21   islamic education           2  3.245
# 2   2020-08-07 12:05:00    male   19                 bit           1  3.245
# 3   2020-08-07 12:06:00  female   22                 law           3  3.245
# 4   2020-08-07 12:13:00    male   23        mathemathics           4  3.245
# ..                  ...     ...  ...                 ...         ...    ...
# 96  2020-07-13 19:56:49  female   21                 bcs           1  3.750
# 97  2020-07-13 21:21:42    male   18         engineering           2  3.245
# 98  2020-07-13 21:22:56  female   19             nursing           3  3.750
# 99  2020-07-13 21:23:57  female   23    pendidikan islam           4  3.750
# 100 2020-07-18 20:16:21    male   20  biomedical science           2  3.245
#
#     marital_status depression anxiety panic_attack treatment
# 0               no        yes      no          yes        no
# 1               no         no     yes           no        no
# 2               no        yes     yes          yes        no
# 3              yes        yes      no           no        no
# 4               no         no      no           no        no
# ..             ...        ...     ...          ...       ...
# 96              no         no     yes           no        no
# 97              no        yes     yes           no        no
# 98             yes        yes      no          yes        no
# 99              no         no      no           no        no
# 100             no         no      no           no        no
#
# [100 rows x 11 columns]

# %%
# @title
grouped_data = data.groupby('gender').agg({
    'age': ['mean', 'min', 'max'],   # Функция sum бессмыслена в рамках задачи
    'study_time': ['mean', 'min', 'max'],
    'cgpa': ['mean', 'min', 'max'],
})

grouped_data
# Out:
#               age         study_time            cgpa
#              mean min max       mean min max    mean    min   max
# gender
# female  20.533333  18  24   2.013333   1   4  3.4076  0.995  3.75
# male    20.520000  18  24   1.880000   1   4  3.2968  0.995  3.75

# %% [markdown]
# Студенты - мужчины с большей вероятностью имеют низкий CGPA.

# %%
# @title
grouped_data = data.groupby('name_of_course').agg({
    'age': ['count', 'mean', 'min', 'max'],   # Функция sum бессмыслена в рамках задачи
    'study_time': ['count', 'mean', 'min', 'max'],
    'cgpa': ['count', 'mean', 'min', 'max'],
})

grouped_data
# Out:
#                           age                    study_time                    \
#                         count       mean min max      count      mean min max
# name_of_course
# accounting                  1  24.000000  24  24          1  3.000000   3   3
# ala                         1  23.000000  23  23          1  1.000000   1   1
# banking studies             1  18.000000  18  18          1  1.000000   1   1
# bcs                        18  20.444444  18  24         18  1.722222   1   4
# benl                        3  20.333333  18  23          3  1.666667   1   3
# biomedical science          4  20.250000  18  24          4  1.750000   1   3
# biotechnology               1  19.000000  19  19          1  3.000000   3   3
# bit                         9  21.333333  19  24          9  2.000000   1   3
# business administration     1  23.000000  23  23          1  2.000000   2   2
# communication               1  24.000000  24  24          1  2.000000   2   2
# cts                         1  18.000000  18  18          1  1.000000   1   1
# diploma tesl                1  23.000000  23  23          1  3.000000   3   3
# econs                       1  23.000000  23  23          1  1.000000   1   1
# engineering                20  20.550000  18  24         20  1.800000   1   4
# enm                         1  24.000000  24  24          1  4.000000   4   4
# fiqh                        1  24.000000  24  24          1  3.000000   3   3
# fiqh fatwa                  1  19.000000  19  19          1  3.000000   3   3
# human resources             1  19.000000  19  19          1  2.000000   2   2
# human sciences              1  18.000000  18  18          1  2.000000   2   2
# irkhs                       1  18.000000  18  18          1  1.000000   1   1
# islamic education           2  19.500000  18  21          2  1.500000   1   2
# it                          1  18.000000  18  18          1  3.000000   3   3
# kenms                       1  18.000000  18  18          1  2.000000   2   2
# kirkhs                      2  20.500000  18  23          2  2.000000   1   3
# koe                         6  19.500000  18  24          6  2.166667   1   3
# kop                         1  24.000000  24  24          1  4.000000   4   4
# law                         3  19.333333  18  22          3  3.000000   3   3
# malcom                      1  18.000000  18  18          1  1.000000   1   1
# marine science              1  18.000000  18  18          1  2.000000   2   2
# mathemathics                1  23.000000  23  23          1  4.000000   4   4
# mhsc                        1  19.000000  19  19          1  3.000000   3   3
# nursing                     2  21.500000  19  24          2  2.500000   2   3
# pendidikan islam            3  21.666667  19  23          3  2.666667   2   4
# psychology                  3  18.666667  18  20          3  1.000000   1   1
# radiography                 1  23.000000  23  23          1  1.000000   1   1
# taasl                       1  23.000000  23  23          1  2.000000   2   2
# usuluddin                   1  20.000000  20  20          1  2.000000   2   2
#
#                          cgpa
#                         count      mean    min    max
# name_of_course
# accounting                  1  3.245000  3.245  3.245
# ala                         1  2.745000  2.745  2.745
# banking studies             1  3.750000  3.750  3.750
# bcs                        18  3.637778  3.245  3.750
# benl                        3  3.245000  3.245  3.245
# biomedical science          4  2.682500  0.995  3.245
# biotechnology               1  0.995000  0.995  0.995
# bit                         9  3.357778  2.745  3.750
# business administration     1  3.245000  3.245  3.245
# communication               1  3.750000  3.750  3.750
# cts                         1  3.750000  3.750  3.750
# diploma tesl                1  3.750000  3.750  3.750
# econs                       1  3.750000  3.750  3.750
# engineering                20  3.347250  2.245  3.750
# enm                         1  3.245000  3.245  3.245
# fiqh                        1  0.995000  0.995  0.995
# fiqh fatwa                  1  3.245000  3.245  3.245
# human resources             1  2.745000  2.745  2.745
# human sciences              1  3.245000  3.245  3.245
# irkhs                       1  3.750000  3.750  3.750
# islamic education           2  3.497500  3.245  3.750
# it                          1  3.245000  3.245  3.245
# kenms                       1  3.750000  3.750  3.750
# kirkhs                      2  3.750000  3.750  3.750
# koe                         6  3.329167  3.245  3.750
# kop                         1  3.245000  3.245  3.245
# law                         3  3.413333  3.245  3.750
# malcom                      1  3.750000  3.750  3.750
# marine science              1  3.750000  3.750  3.750
# mathemathics                1  3.245000  3.245  3.245
# mhsc                        1  3.245000  3.245  3.245
# nursing                     2  3.750000  3.750  3.750
# pendidikan islam            3  3.581667  3.245  3.750
# psychology                  3  3.750000  3.750  3.750
# radiography                 1  3.245000  3.245  3.245
# taasl                       1  3.750000  3.750  3.750
# usuluddin                   1  3.245000  3.245  3.245

# %% [markdown]
# Значения столбца *count* везде одинаковы, т.к. функция считает количесво значений в столбце. Оно может быть различным, если присутствуют нулевые значения, однако мы выполнили работу над пропущенными значениями, поэтому их нет.

# %% [markdown]
# ## 6. Поиск закономерностей, варианты решения бизнес-задачи

# %% [markdown]
# > Используя функции и методы библиотеки Pandas (или иных библиотек)
# проведите исследовательский анализ данных, способствующий решению
# поставленной бизнес-задачи. Здесь нет конкретных инструкций и заданий –
# поищите интересные закономерности в данных.

# %% [markdown]
# Установим зависимость между названием курса и наличием психических отклонений.

# %%
# @title
data.pivot_table(index='name_of_course', columns='depression', values='timestamp', aggfunc='count')
# Out:
# depression                 no  yes
# name_of_course
# accounting                1.0  NaN
# ala                       NaN  1.0
# banking studies           1.0  NaN
# bcs                      13.0  5.0
# benl                      1.0  2.0
# biomedical science        4.0  NaN
# biotechnology             1.0  NaN
# bit                       4.0  5.0
# business administration   1.0  NaN
# communication             NaN  1.0
# cts                       1.0  NaN
# diploma tesl              1.0  NaN
# econs                     NaN  1.0
# engineering              13.0  7.0
# enm                       NaN  1.0
# fiqh                      1.0  NaN
# fiqh fatwa                1.0  NaN
# human resources           1.0  NaN
# human sciences            1.0  NaN
# irkhs                     1.0  NaN
# islamic education         2.0  NaN
# it                        1.0  NaN
# kenms                     1.0  NaN
# kirkhs                    2.0  NaN
# koe                       4.0  2.0
# kop                       1.0  NaN
# law                       1.0  2.0
# malcom                    NaN  1.0
# marine science            NaN  1.0
# mathemathics              1.0  NaN
# mhsc                      NaN  1.0
# nursing                   1.0  1.0
# pendidikan islam          2.0  1.0
# psychology                1.0  2.0
# radiography               1.0  NaN
# taasl                     1.0  NaN
# usuluddin                 NaN  1.0

# %%
# @title
data.pivot_table(index='name_of_course', columns='anxiety', values='timestamp', aggfunc='count')
# Out:
# anxiety                    no  yes
# name_of_course
# accounting                1.0  NaN
# ala                       1.0  NaN
# banking studies           1.0  NaN
# bcs                      12.0  6.0
# benl                      2.0  1.0
# biomedical science        4.0  NaN
# biotechnology             1.0  NaN
# bit                       1.0  8.0
# business administration   1.0  NaN
# communication             NaN  1.0
# cts                       1.0  NaN
# diploma tesl              1.0  NaN
# econs                     NaN  1.0
# engineering              16.0  4.0
# enm                       NaN  1.0
# fiqh                      1.0  NaN
# fiqh fatwa                1.0  NaN
# human resources           1.0  NaN
# human sciences            1.0  NaN
# irkhs                     NaN  1.0
# islamic education         1.0  1.0
# it                        1.0  NaN
# kenms                     NaN  1.0
# kirkhs                    2.0  NaN
# koe                       2.0  4.0
# kop                       NaN  1.0
# law                       2.0  1.0
# malcom                    1.0  NaN
# marine science            NaN  1.0
# mathemathics              1.0  NaN
# mhsc                      1.0  NaN
# nursing                   2.0  NaN
# pendidikan islam          3.0  NaN
# psychology                1.0  2.0
# radiography               1.0  NaN
# taasl                     1.0  NaN
# usuluddin                 1.0  NaN

# %%
# @title
data.pivot_table(index='name_of_course', columns='panic_attack', values='timestamp', aggfunc='count')
# Out:
# panic_attack               no  yes
# name_of_course
# accounting                1.0  NaN
# ala                       NaN  1.0
# banking studies           1.0  NaN
# bcs                      13.0  5.0
# benl                      3.0  NaN
# biomedical science        4.0  NaN
# biotechnology             1.0  NaN
# bit                       5.0  4.0
# business administration   1.0  NaN
# communication             NaN  1.0
# cts                       NaN  1.0
# diploma tesl              NaN  1.0
# econs                     1.0  NaN
# engineering              14.0  6.0
# enm                       NaN  1.0
# fiqh                      NaN  1.0
# fiqh fatwa                1.0  NaN
# human resources           1.0  NaN
# human sciences            NaN  1.0
# irkhs                     NaN  1.0
# islamic education         2.0  NaN
# it                        NaN  1.0
# kenms                     1.0  NaN
# kirkhs                    2.0  NaN
# koe                       4.0  2.0
# kop                       1.0  NaN
# law                       2.0  1.0
# malcom                    1.0  NaN
# marine science            NaN  1.0
# mathemathics              1.0  NaN
# mhsc                      NaN  1.0
# nursing                   1.0  1.0
# pendidikan islam          2.0  1.0
# psychology                2.0  1.0
# radiography               1.0  NaN
# taasl                     NaN  1.0
# usuluddin                 1.0  NaN

# %% [markdown]
# Выясним, с какими заболеваниями чаще обращаются за помощью.

# %%
# @title
data.where((data['panic_attack'] == 'yes') & (data['treatment'] == 'yes')).count()
# Out:
# timestamp         4
# gender            4
# age               4
# name_of_course    4
# study_time        4
# cgpa              4
# marital_status    4
# depression        4
# anxiety           4
# panic_attack      4
# treatment         4
# dtype: int64

# %%
# @title
data.where((data['anxiety'] == 'yes') & (data['treatment'] == 'yes')).count()
# Out:
# timestamp         3
# gender            3
# age               3
# name_of_course    3
# study_time        3
# cgpa              3
# marital_status    3
# depression        3
# anxiety           3
# panic_attack      3
# treatment         3
# dtype: int64

# %%
# @title
data.where((data['depression'] == 'yes') & (data['treatment'] == 'yes')).count()
# Out:
# timestamp         6
# gender            6
# age               6
# name_of_course    6
# study_time        6
# cgpa              6
# marital_status    6
# depression        6
# anxiety           6
# panic_attack      6
# treatment         6
# dtype: int64

# %% [markdown]
# Кто раньше вступает в брак по полу.

# %%
# @title
data.pivot_table(values='age', index=('gender','marital_status'), aggfunc='mean')
# Out:
#                              age
# gender marital_status
# female no              20.274194
#        yes             21.769231
# male   no              20.818182
#        yes             18.333333

# %%
# @title
data.query('name_of_course == "islamic education"')
# Out:
#              timestamp  gender  age     name_of_course  study_time   cgpa  \
# 1  2020-08-07 12:04:00    male   21  islamic education           2  3.245
# 95 2020-07-13 19:08:32  female   18  islamic education           1  3.750
#
#    marital_status depression anxiety panic_attack treatment
# 1              no         no     yes           no        no
# 95             no         no      no           no        no

# %% [markdown]
# Статус первокурсников, которым за 20.

# %%
# @title
df2 = data.pivot_table(index='marital_status', values=['age', 'study_time'])
df2.query("age>20 and study_time<2")
# Out:
#                       age  study_time
# marital_status
# no              20.416667    1.880952

# %%
# @title
count_course = data['name_of_course'].value_counts()

# Отфильтруем курсы, на которых больше 1го студента
filtered_courses = count_course[count_course > 1].index

# Группируем данные по курсам, где количество студентов больше 1го
grouped_data = data[data['name_of_course'].isin(filtered_courses)].groupby('name_of_course').agg({
    'age': ['count', 'min', 'max', 'mean'],
    'study_time': ['count', 'min', 'max', 'mean'],
    'cgpa': ['count', 'min', 'max', 'mean'],
})

grouped_data
# Out:
#                      age                    study_time                    \
#                    count min max       mean      count min max      mean
# name_of_course
# bcs                   18  18  24  20.444444         18   1   4  1.722222
# benl                   3  18  23  20.333333          3   1   3  1.666667
# biomedical science     4  18  24  20.250000          4   1   3  1.750000
# bit                    9  19  24  21.333333          9   1   3  2.000000
# engineering           20  18  24  20.550000         20   1   4  1.800000
# islamic education      2  18  21  19.500000          2   1   2  1.500000
# kirkhs                 2  18  23  20.500000          2   1   3  2.000000
# koe                    6  18  24  19.500000          6   1   3  2.166667
# law                    3  18  22  19.333333          3   3   3  3.000000
# nursing                2  19  24  21.500000          2   2   3  2.500000
# pendidikan islam       3  19  23  21.666667          3   2   4  2.666667
# psychology             3  18  20  18.666667          3   1   1  1.000000
#
#                     cgpa
#                    count    min    max      mean
# name_of_course
# bcs                   18  3.245  3.750  3.637778
# benl                   3  3.245  3.245  3.245000
# biomedical science     4  0.995  3.245  2.682500
# bit                    9  2.745  3.750  3.357778
# engineering           20  2.245  3.750  3.347250
# islamic education      2  3.245  3.750  3.497500
# kirkhs                 2  3.750  3.750  3.750000
# koe                    6  3.245  3.750  3.329167
# law                    3  3.245  3.750  3.413333
# nursing                2  3.750  3.750  3.750000
# pendidikan islam       3  3.245  3.750  3.581667
# psychology             3  3.750  3.750  3.750000

# %%
# @title
years = data.sort_values(['study_time','age'], ascending=True)  # По возрастанию времени обучения
years[80:100]
# Out:
#              timestamp  gender  age    name_of_course  study_time   cgpa  \
# 3  2020-08-07 12:06:00  female   22               law           3  3.245
# 24 2020-08-07 13:17:00  female   23               bcs           3  3.750
# 56 2020-08-07 16:08:00    male   23            kirkhs           3  3.750
# 90 2020-07-13 13:57:11  female   23      diploma tesl           3  3.750
# 11 2020-08-07 12:39:00  female   24       engineering           3  3.750
# 15 2020-08-07 12:43:00    male   24               bcs           3  3.750
# 16 2020-08-07 12:46:00  female   24        accounting           3  3.245
# 28 2020-08-07 13:58:00  female   24               bit           3  3.750
# 40 2020-08-07 14:57:00  female   24               bit           3  3.245
# 49 2020-08-07 15:18:00  female   24               bcs           3  3.750
# 74 2020-09-07 11:43:00    male   24               bit           3  3.750
# 94 2020-07-13 17:30:44  female   24              fiqh           3  0.995
# 47 2020-08-07 15:14:00  female   18       engineering           4  3.750
# 79 2020-07-13 10:10:30  female   18       engineering           4  3.750
# 41 2020-08-07 14:57:00  female   22       engineering           4  3.750
# 4  2020-08-07 12:13:00    male   23      mathemathics           4  3.245
# 99 2020-07-13 21:23:57  female   23  pendidikan islam           4  3.750
# 17 2020-08-07 12:52:00  female   24               enm           4  3.245
# 29 2020-08-07 14:05:00  female   24               bcs           4  3.750
# 69 2020-08-07 19:32:00  female   24               kop           4  3.245
#
#    marital_status depression anxiety panic_attack treatment
# 3             yes        yes      no           no        no
# 24             no        yes     yes          yes        no
# 56             no         no      no           no        no
# 90             no         no      no          yes        no
# 11            yes        yes      no           no        no
# 15             no         no      no           no        no
# 16             no         no      no           no        no
# 28            yes        yes     yes          yes       yes
# 40             no         no     yes           no        no
# 49             no         no      no          yes        no
# 74             no         no     yes           no        no
# 94             no         no      no          yes        no
# 47             no         no      no           no        no
# 79             no         no      no           no        no
# 41             no         no      no           no        no
# 4              no         no      no           no        no
# 99             no         no      no           no        no
# 17            yes        yes     yes          yes        no
# 29             no         no      no           no        no
# 69             no         no     yes           no        no

# %% [markdown]
#  **Психологические расстройства:**
#    - **Депрессия:**
#      - Всего 35 случаев.
#      - Из них 16 студентов в браке.
#      - 6 парней и 29 девушек.
#      - 6 обратились за помощью.
#      - Наибольшее количество случаев наблюдается на курсах: ala, benl, bit, communication, econs, law/s, malcom, marine science, mathematics, mhsc, pendidikan islam, psychology, usuluddin.
#      - 11 студентов с депрессией находятся на 3 и 4 курсах.
#      - Девушки на 1 и 2 курсах, не состоящие в браке страдают чаще.
#
#    - **Тревожность:**
#      - Всего 34 случая.
#      - Из них 7 студентов в браке.
#      - 10 парней и 24 девушки.
#      - 3 лечатся.
#      - 10 студентов с тревожностью находятся на 3 и 4 курсах.
#      - Наиболее распространенные курсы: bit, communication, econs, enm, irkhs, islamic education, kenms, koe, kop, marine science, psychology.
#
#    - **Панические атаки:**
#      - Всего 33 случая.
#      - 22 человека на 3 и 4 курсе.
#      - 7 человек в браке.
#      - 25 девушек, 8 парней.
#      - Чаще страдают, если есть и депрессия и тревожность, либо если нет ни депрессии, ни тревожности.
#      - Лечатся 4 студента.
#      - Больший процент наблюдается на курсах: ala, bit, cts, diploma tesl, engineering, enm, fiqh, human sciences, irkhs, laws, malcom, mhsc, nursing.

# %% [markdown]
# ## 7. Выводы к разделу 2

# %% [markdown]
# >  Сделайте промежуточные выводы о проделанной работе.

# %% [markdown]
# При помощи индексации было выявлено, что:
# - Как минимум треть опрошенных студентов страдает от какого-либо психологического расстройства.
# - Большему влиянию подвержены более молодые студенты.

# %% [markdown]
# Сортировка помогла выявить, что:
# - В опросе приняли участие студенты от 18 до 24 лет.
# - Диапазон cgpa очень широк: 0.995-3.75. Это значит, что установить от чего зависят оценки можно довольно точно.

# %% [markdown]
# Фильтрация данных позволила установить, что:
# - Девушки обращаются за лечением чаще, чем парни, несмотря на то, что последние более склонны к проблемам с психикой.
# - Люди, состоящие в браке, меньше подвержены психологическикм проблемам, одноко хуже учатся.
# - Студенты старших курсов с меньшей вероятностью обратятся за лечением.

# %% [markdown]
# Сводные таблицы показали, как различные факторы (пол, срок обучения и т.д.) влияют на психическое состояние студентов:
# - Все получающее лечение находятся в депрессии.
# - Большая часть университета получает высокие отметки, а возраст не имеет  в этом большой роли.
# - Большая часть опрошенных обучается на курсах *bcs* (Bachelor of Computer Science - Компьютерные науки, бакалавриат) и *engineering* (Инженерия)

# %% [markdown]
# Группировка и агрегатные функции позволили:
# - Выявить, что девушки в основном учатся лучше парней.
# - Ещё раз просмотреть средний балл у разных образовательных курсов.

# %% [markdown]
# Также можно отметить, что:
# - Гуманитарные специальности чаще сталкиваются с депрессией, а технические с тревожностью и паническими атаками.
# - Люди с депрессией чаще обращаются за помощью к специалистам.
# - Парни вступают в брак раньше, чем девушки.

# %% [markdown]
# # Графический анализ данных

# %% [markdown]
# >  Постройте не менее 3 различных диаграмм – библиотека Matplotlib, 2
# различных диаграмм – библиотека Seaborn, для наглядного представления ранее полученных результатов.
#
# > Настройте диаграммы (оси, сетка, легенда, тики и т.д.) таким образом, чтобы они были читабельны без обращения к данным.

# %% [markdown]
# ## 1. Диаграммы, библиотека Matplotlib

# %%
# @title
# Диаграмма распределения среднего возраста по названию курса
plt.figure(figsize=(10, 6))
sns.barplot(x=grouped_data.index, y=grouped_data['age']['mean'], palette='viridis')
plt.title('Средний возраст по названию курса')
plt.xlabel('Название курса')
plt.ylabel('Средний возраст')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend(['Средний возраст'])
plt.show()
# Out:
# <ipython-input-90-87197788ddf0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=grouped_data.index, y=grouped_data['age']['mean'], palette='viridis')

# %%
# @title
# Диаграмма распределения среднего значения CGPA по названию курса
plt.figure(figsize=(12, 6))
sns.barplot(x=grouped_data.index, y=grouped_data['cgpa']['mean'], palette='coolwarm')
plt.title('Средний CGPA по названиям курсов')
plt.xlabel('Название курса')
plt.ylabel('Средний CGPA')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend(['Средний CGPA'])
plt.show()
# Out:
# <ipython-input-91-f59d46079dbe>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=grouped_data.index, y=grouped_data['cgpa']['mean'], palette='coolwarm')

# %%
# @title
# Точечный график CGPA по времени учёбы
plt.figure(figsize=(10, 6))
plt.scatter(data['study_time'], data['cgpa'], alpha=0.6)
plt.title('CGPA по времени учёбы')
plt.xlabel('Год обучения')
plt.ylabel('CGPA')
plt.grid(True)
plt.show()

# %%
# Распределение психологических расстройств по курсам
plt.figure(figsize=(10, 6))
sns.countplot(x='name_of_course', hue='depression', data=data)
plt.title('Распределение депрессии по курсам')
plt.xlabel('Курс')
plt.ylabel('Количество студентов')
plt.xticks(rotation=90)
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='name_of_course', hue='anxiety', data=data)
plt.title('Распределение тревожности по курсам')
plt.xlabel('Курс')
plt.ylabel('Количество студентов')
plt.xticks(rotation=90)
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='name_of_course', hue='panic_attack', data=data)
plt.title('Распределение панических атак по курсам')
plt.xlabel('Курс')
plt.ylabel('Количество студентов')
plt.xticks(rotation=90)
plt.legend(loc='best')
plt.show()

# %%
# @title
# CGPA по полу
plt.figure(figsize=(6, 4))
sns.swarmplot(x='gender', y='cgpa', data=data)
plt.title('Распределение CGPA по полу')
plt.xlabel('Пол')
plt.ylabel('CGPA')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Распределение психологических расстройств по полу
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', hue='depression', data=data)
plt.title('Распределение депрессии по полу')
plt.xlabel('Пол')
plt.ylabel('Количество студентов')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', hue='anxiety', data=data)
plt.title('Распределение тревожности по полу')
plt.xlabel('Пол')
plt.ylabel('Количество студентов')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', hue='panic_attack', data=data)
plt.title('Распределение панических атак по полу')
plt.xlabel('Пол')
plt.ylabel('Количество студентов')
plt.show()

# %% [markdown]
# ## 2. Диаграммы, библиотека Seaborn

# %%
# @title
# Диаграмма boxplot для изучения влияния лечения на CGPA
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='treatment', y='cgpa', palette='Set1')
plt.title('Уровень CGPA в зависимости от лечения')
plt.xlabel('Лечение')
plt.ylabel('CGPA')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-100-128f0f7aab13>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='treatment', y='cgpa', palette='Set1')

# %%
# @title
# Диаграмма для изучения зависимости состояния здоровья от времени учёбы
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='study_time', hue='panic_attack', palette='pastel')
plt.title('Период обучения и панические атаки')
plt.xlabel('Год обучения')
plt.ylabel('Количество студентов')
plt.grid(True)
plt.legend(title='Паническая атака')
plt.show()

# %%
# @title
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(10, 8))
sns.swarmplot(x='name_of_course', y='cgpa', data=data, ax=ax)
plt.title('Средний балл на каждом курсе')

ax.set_xlabel('Направление обучения')
ax.set_ylabel('Балл')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 55.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 22.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <ipython-input-102-bc211ca9c426>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
# @title
# CGPA по возрасту
plt.figure(figsize=(10, 6))
sns.boxplot(x='age', y='cgpa', data=data)
plt.title('Распределение CGPA по возрасту')
plt.xlabel('Возраст')
plt.ylabel('CGPA')
plt.show()

# %%
# Распределение психологических расстройств по семейному положению
plt.figure(figsize=(8, 6))
sns.countplot(x='marital_status', hue='depression', data=data)
plt.title('Распределение депрессии по семейному положению')
plt.xlabel('Семейное положение')
plt.ylabel('Количество студентов')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='marital_status', hue='anxiety', data=data)
plt.title('Распределение тревожности по семейному положению')
plt.xlabel('Семейное положение')
plt.ylabel('Количество студентов')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='marital_status', hue='panic_attack', data=data)
plt.title('Распределение панических атак по семейному положению')
plt.xlabel('Семейное положение')
plt.ylabel('Количество студентов')
plt.show()

# %% [markdown]
# ## 3. "Портрет" типичного потребителя (вывод к разделу 3)

# %% [markdown]
# > На основе полученных данных составьте «портрет» типичного
# потребителя в рамках исследуемой предметной области

# %% [markdown]
# Студенты с низким cgpa и наличием психологических расстройств являются потребителями в рамках поставленной задачи.

# %% [markdown]
# Наиболее низкий сgpa был замечен у студентов:
# 1. 1 и 3 года обучения.
# 2. Специальностей: biomedical science, benl, bit, engineering, koe.
# 3. Мужского пола.
# 4. Возрастом 19 и 24 лет.

# %% [markdown]
# # Общий вывод по проекту

# %% [markdown]
# После тщательного анализа данных, предоставленных в датасете, удалось установить, что психологическое здоровье студентов и их успеваемость довольно сильно зависят от друг друга. Студенты с психологическими проблемами имиеют склонность к плохой успеваемости.

# %% [markdown]
# Плохая успеваемость и сильная психологическая нагрузка была выявлена у студентов:
# 1. Получающих лечение на курсе engineering.
# 2. Неполучающих лечение biomedical science, biotechnology, fiqh, human resources.

# %% [markdown]
# От депрессии и тревоги наиболее часто страдают девушки на начальных курсах обучения, не состоящие в браке. Панические атаки чаще испытывают парни - студенты старших курсов, не состоящие в браке.

# %% [markdown]
# Низкий cgpa также можно заметить у студентов без каких либо из предложенных проблем (депрессия, тревожность, панические атаки). Среди них есть те, кто состоит в браке. Вполне возможно, что наличие супруги/супруга может отвлекать от учебы, но иметь большую роль как психологическая поддержка.
#
# Однако, некоторые студенты имеют хорошую успеваемость, несмотря на психологические трудности. Вполне возможно, что депрессия и прочие заболевания являются следствием усердной и напряжённой учёбы. В связи с этим, можно предложить следующие введения не только в университетах, но и прочих образовательных учреждениях:

# %% [markdown]
# - Разработать программы поддержки для студентов, испытывающих психологические расстройства, включая обязательные консультации с психологом/психотерапевтом для тяжёлых форм заболеваний.
# - Обеспечить доступ к психологической помощи и консультированию для всех студентов, т.е.бюджетность и удобство лечения.
# - Создать благоприятную атмосферу в учебном заведении, которая бы способствовала открытому обсуждению вопросов психического здоровья.
# - Предоставить информацию о первых признаках наличия отклонений в психике и способах борьбы с эмоциональным давлением.

# %% [markdown]
# Данные выводы являются лишь предварительной картиной и необходимо провести более глубокое исследование для получения более точной информации, с учетом дополнительных факторов, таких как обстановка в семье, финансовое положение, доступность ресурсов и т.д.
